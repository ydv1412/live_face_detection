# %%
from tensorflow.keras.applications import InceptionV3
import keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
model = InceptionV3(include_top = False , weights="imagenet", input_shape = (224,224,3))
# Out:
# ...
# 87924736/87910968 [==============================] - 45s 1us/step

# %%
for layers in model.layers:
    layers.trainable = False

# %%
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
base_model_output = model.layers[-1].output
x = keras.layers.Flatten()(base_model_output)
x = keras.layers.Dense(1024 , activation = 'relu')(x)
x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(256 , activation = 'relu')(x)
x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(32 , activation = 'relu')(x)
x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(7 , activation = 'softmax')(x)

final_model = keras.Model(model.input , x)

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
opt = tf.keras.optimizers.Adam()
final_model.compile(optimizer = opt , loss = 'sparse_categorical_crossentropy' , metrics = ['acc'])

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    rotation_range = 10,
    horizontal_flip = True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode = 'nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory('archive\\train' ,target_size = (224,224), batch_size= 64 , class_mode = 'binary')
# Out:
# Found 28709 images belonging to 7 classes.

# %%
test_data = test_datagen.flow_from_directory('archive\\test' ,target_size = (224,224), batch_size= 64 , class_mode = 'binary')
# Out:
# Found 7178 images belonging to 7 classes.

# %%
history = final_model.fit(train_data, epochs=50, validation_data=test_data)
# Out:
# Epoch 1/50
# 449/449 [==============================] - 26628s 59s/step - loss: 1.5112 - acc: 0.4170 - val_loss: 1.3936 - val_acc: 0.4831
# Epoch 2/50
# 449/449 [==============================] - 1043s 2s/step - loss: 1.5165 - acc: 0.4200 - val_loss: 1.4136 - val_acc: 0.4801
# Epoch 3/50
# 449/449 [==============================] - 1037s 2s/step - loss: 1.5073 - acc: 0.4141 - val_loss: 1.3847 - val_acc: 0.4795
# Epoch 4/50
# 449/449 [==============================] - 1039s 2s/step - loss: 1.5105 - acc: 0.4195 - val_loss: 1.4079 - val_acc: 0.4813
# Epoch 5/50
# 449/449 [==============================] - 1128s 3s/step - loss: 1.5063 - acc: 0.4225 - val_loss: 1.4032 - val_acc: 0.4805
# Epoch 6/50
# 449/449 [==============================] - 4990s 11s/step - loss: 1.5064 - acc: 0.4179 - val_loss: 1.4072 - val_acc: 0.4843
# Epoch 7/50
# 449/449 [==============================] - 1244s 3s/step - loss: 1.5008 - acc: 0.4230 - val_loss: 1.3925 - val_acc: 0.4879
# Epoch 8/50
# ...

# %%
final_model.save_weights('final_model.h5')

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
history = final_model.fit(train_data, epochs=185, validation_data=test_data)
# Out:
# Epoch 1/185
# 449/449 [==============================] - 1153s 3s/step - loss: 1.5451 - acc: 0.4100 - val_loss: 1.4385 - val_acc: 0.4635
# Epoch 2/185
# 449/449 [==============================] - 1499s 3s/step - loss: 1.5511 - acc: 0.4080 - val_loss: 1.4606 - val_acc: 0.4667
# Epoch 3/185
# 449/449 [==============================] - 1616s 4s/step - loss: 1.5405 - acc: 0.4108 - val_loss: 1.4567 - val_acc: 0.4772
# Epoch 4/185
# 449/449 [==============================] - 1226s 3s/step - loss: 1.5461 - acc: 0.4068 - val_loss: 1.4448 - val_acc: 0.4664
# Epoch 5/185
# 449/449 [==============================] - 1194s 3s/step - loss: 1.5325 - acc: 0.4079 - val_loss: 1.3957 - val_acc: 0.4815
# Epoch 6/185
# 449/449 [==============================] - 1174s 3s/step - loss: 1.5282 - acc: 0.4117 - val_loss: 1.4055 - val_acc: 0.4830
# Epoch 7/185
# 449/449 [==============================] - 1120s 2s/step - loss: 1.5334 - acc: 0.4113 - val_loss: 1.4089 - val_acc: 0.4657
# Epoch 8/185
# ...
