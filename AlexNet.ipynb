# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
AlexNet = Sequential()

#1st Convolutional Layer
AlexNet.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())
# 1st Fully Connected Layer
AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1000))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(7))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 56, 56, 96)        34944
#
#  batch_normalization_9 (Batc  (None, 56, 56, 96)       384
#  hNormalization)
#
#  activation_9 (Activation)   (None, 56, 56, 96)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 256)       614656
#
#  batch_normalization_10 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  activation_10 (Activation)  (None, 28, 28, 256)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 384)       885120
#
#  batch_normalization_11 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_11 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 384)       1327488
#
#  batch_normalization_12 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_12 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 256)       884992
#
#  batch_normalization_13 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  activation_13 (Activation)  (None, 14, 14, 256)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_4 (Dense)             (None, 4096)              51384320
#
#  batch_normalization_14 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  activation_14 (Activation)  (None, 4096)              0
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_15 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  activation_15 (Activation)  (None, 4096)              0
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 1000)              4097000
#
#  batch_normalization_16 (Bat  (None, 1000)             4000
#  chNormalization)
#
#  activation_16 (Activation)  (None, 1000)              0
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  dense_7 (Dense)             (None, 7)                 7007
#
#  batch_normalization_17 (Bat  (None, 7)                28
#  chNormalization)
#
#  activation_17 (Activation)  (None, 7)                 0
#
# =================================================================
# Total params: 76,059,139
# Trainable params: 76,037,989
# Non-trainable params: 21,150
# _________________________________________________________________

# %%
train_generator = ImageDataGenerator(rescale = 1/255.0) 

test_generator = ImageDataGenerator(rescale = 1/255.0 , validation_split = 0.5)

# %%
train_Data = train_generator.flow_from_directory('archive\\train' ,target_size = (224,224), batch_size= 512 , class_mode = 'binary')
# Out:
# Found 28709 images belonging to 7 classes.

# %%
validation_Data = test_generator.flow_from_directory('archive\\test' ,target_size = (224,224), batch_size= 512 , class_mode = 'binary' , subset = 'validation')
# Out:
# Found 3587 images belonging to 7 classes.

# %%
test_Data = test_generator.flow_from_directory('archive\\test' ,target_size = (224,224), batch_size= 512 , class_mode = 'binary' , subset = "training" )
# Out:
# Found 3591 images belonging to 7 classes.

# %%
AlexNet.compile(loss = 'sparse_categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])

# %%
AlexNet.fit(train_Data, epochs=25, validation_data=validation_Data)
# Out:
# Epoch 1/25
# 57/57 [==============================] - 1360s 24s/step - loss: 1.6148 - accuracy: 0.4033 - val_loss: 6.4772 - val_accuracy: 0.1589
# Epoch 2/25
# 57/57 [==============================] - 1446s 25s/step - loss: 1.3328 - accuracy: 0.5245 - val_loss: 2.1047 - val_accuracy: 0.3758
# Epoch 3/25
# 57/57 [==============================] - 1425s 25s/step - loss: 1.2010 - accuracy: 0.5822 - val_loss: 2.0110 - val_accuracy: 0.3496
# Epoch 4/25
# 57/57 [==============================] - 1328s 23s/step - loss: 1.1033 - accuracy: 0.6198 - val_loss: 1.3803 - val_accuracy: 0.5068
# Epoch 5/25
# 57/57 [==============================] - 1602s 28s/step - loss: 0.9936 - accuracy: 0.6651 - val_loss: 1.8487 - val_accuracy: 0.3465
# Epoch 6/25
# 57/57 [==============================] - 1944s 34s/step - loss: 0.9049 - accuracy: 0.6985 - val_loss: 1.4468 - val_accuracy: 0.4725
# Epoch 7/25
# 57/57 [==============================] - 1865s 33s/step - loss: 0.7817 - accuracy: 0.7533 - val_loss: 1.5904 - val_accuracy: 0.4539
# Epoch 8/25
# 57/57 [==============================] - 1298s 23s/step - loss: 0.6628 - accuracy: 0.8039 - val_loss: 1.3596 - val_accuracy: 0.5389
# Epoch 9/25
# 57/57 [==============================] - 1274s 22s/step - loss: 0.5794 - accuracy: 0.8332 - val_loss: 1.3040 - val_accuracy: 0.5526
# Epoch 10/25
# 57/57 [==============================] - 1276s 22s/step - loss: 0.4574 - accuracy: 0.8808 - val_loss: 1.3949 - val_accuracy: 0.5445
# Epoch 11/25
# 57/57 [==============================] - 1268s 22s/step - loss: 0.3237 - accuracy: 0.9340 - val_loss: 1.4686 - val_accuracy: 0.5344
# Epoch 12/25
# 57/57 [==============================] - 1272s 23s/step - loss: 0.3017 - accuracy: 0.9345 - val_loss: 1.3234 - val_accuracy: 0.5576
# Epoch 13/25
# 57/57 [==============================] - 1282s 22s/step - loss: 0.2112 - accuracy: 0.9672 - val_loss: 1.2881 - val_accuracy: 0.5827
# Epoch 14/25
# 57/57 [==============================] - 1265s 22s/step - loss: 0.2036 - accuracy: 0.9653 - val_loss: 1.4563 - val_accuracy: 0.5163
# Epoch 15/25
# 57/57 [==============================] - 1263s 22s/step - loss: 0.1506 - accuracy: 0.9809 - val_loss: 1.2199 - val_accuracy: 0.6278
# Epoch 16/25
# 57/57 [==============================] - 1271s 22s/step - loss: 0.1348 - accuracy: 0.9835 - val_loss: 1.2306 - val_accuracy: 0.6206
# Epoch 17/25
# 57/57 [==============================] - 1267s 22s/step - loss: 0.1068 - accuracy: 0.9893 - val_loss: 1.2723 - val_accuracy: 0.6013
# Epoch 18/25
# 57/57 [==============================] - 9107s 162s/step - loss: 0.0994 - accuracy: 0.9897 - val_loss: 1.3034 - val_accuracy: 0.6052
# Epoch 19/25
# 57/57 [==============================] - 1343s 24s/step - loss: 0.0809 - accuracy: 0.9931 - val_loss: 1.2054 - val_accuracy: 0.6242
# Epoch 20/25
# 57/57 [==============================] - 4103s 73s/step - loss: 0.0759 - accuracy: 0.9929 - val_loss: 1.2280 - val_accuracy: 0.6281
# Epoch 21/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AMANKH~1\AppData\Local\Temp/ipykernel_10088/847600261.py in <module>
# ----> 1 AlexNet.fit(train_Data, epochs=25, validation_data=validation_Data)
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\users\aman khan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
AlexNet.save_weights('alexnet.h5')

# %%
AlexNet2 = Sequential()

#1st Convolutional Layer
AlexNet2.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='same'))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
AlexNet2.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet2.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
AlexNet2.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet2.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))

#4th Convolutional Layer
AlexNet2.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))

#5th Convolutional Layer
AlexNet2.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
AlexNet2.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet2.add(Flatten())
# 1st Fully Connected Layer
AlexNet2.add(Dense(4096, input_shape=(32,32,3,)))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
# Add Dropout to prevent overfitting
AlexNet2.add(Dropout(0.5))

#2nd Fully Connected Layer
AlexNet2.add(Dense(4096))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
#Add Dropout
AlexNet2.add(Dropout(0.5))

#3rd Fully Connected Layer
AlexNet2.add(Dense(1000))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('relu'))
#Add Dropout
AlexNet2.add(Dropout(0.5))

#Output Layer
AlexNet2.add(Dense(7))
AlexNet2.add(BatchNormalization())
AlexNet2.add(Activation('softmax'))

#Model Summary
AlexNet2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 56, 56, 96)        34944
#
#  batch_normalization_18 (Bat  (None, 56, 56, 96)       384
#  chNormalization)
#
#  activation_18 (Activation)  (None, 56, 56, 96)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 256)       614656
#
#  batch_normalization_19 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  activation_19 (Activation)  (None, 28, 28, 256)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 384)       885120
#
#  batch_normalization_20 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_20 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 384)       1327488
#
#  batch_normalization_21 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_21 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 256)       884992
#
#  batch_normalization_22 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  activation_22 (Activation)  (None, 14, 14, 256)       0
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_8 (Dense)             (None, 4096)              51384320
#
#  batch_normalization_23 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  activation_23 (Activation)  (None, 4096)              0
#
#  dropout_6 (Dropout)         (None, 4096)              0
#
#  dense_9 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_24 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  activation_24 (Activation)  (None, 4096)              0
#
#  dropout_7 (Dropout)         (None, 4096)              0
#
#  dense_10 (Dense)            (None, 1000)              4097000
#
#  batch_normalization_25 (Bat  (None, 1000)             4000
#  chNormalization)
#
#  activation_25 (Activation)  (None, 1000)              0
#
#  dropout_8 (Dropout)         (None, 1000)              0
#
#  dense_11 (Dense)            (None, 7)                 7007
#
#  batch_normalization_26 (Bat  (None, 7)                28
#  chNormalization)
#
#  activation_26 (Activation)  (None, 7)                 0
#
# =================================================================
# Total params: 76,059,139
# Trainable params: 76,037,989
# Non-trainable params: 21,150
# _________________________________________________________________

# %%
AlexNet2.compile(loss = 'sparse_categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])

# %%
history = AlexNet2.fit(train_Data, epochs=15, validation_data=validation_Data)
# Out:
# Epoch 1/15
# 57/57 [==============================] - 1761s 30s/step - loss: 1.7401 - accuracy: 0.3522 - val_loss: 7.0069 - val_accuracy: 0.0513
# Epoch 2/15
# 57/57 [==============================] - 1421s 25s/step - loss: 1.4333 - accuracy: 0.4801 - val_loss: 2.1281 - val_accuracy: 0.2963
# Epoch 3/15
# 57/57 [==============================] - 1402s 25s/step - loss: 1.3066 - accuracy: 0.5319 - val_loss: 1.6610 - val_accuracy: 0.4073
# Epoch 4/15
# 57/57 [==============================] - 1385s 24s/step - loss: 1.1848 - accuracy: 0.5866 - val_loss: 1.4496 - val_accuracy: 0.4784
# Epoch 5/15
# 57/57 [==============================] - 1366s 24s/step - loss: 1.0970 - accuracy: 0.6211 - val_loss: 1.3866 - val_accuracy: 0.5118
# Epoch 6/15
# 57/57 [==============================] - 1388s 24s/step - loss: 1.0022 - accuracy: 0.6624 - val_loss: 1.3356 - val_accuracy: 0.5160
# Epoch 7/15
# 57/57 [==============================] - 1520s 27s/step - loss: 0.9258 - accuracy: 0.6930 - val_loss: 1.4847 - val_accuracy: 0.4700
# Epoch 8/15
# 57/57 [==============================] - 1418s 25s/step - loss: 0.7921 - accuracy: 0.7471 - val_loss: 1.4039 - val_accuracy: 0.5057
# Epoch 9/15
# 57/57 [==============================] - 1665s 29s/step - loss: 0.7073 - accuracy: 0.7796 - val_loss: 1.5237 - val_accuracy: 0.4764
# Epoch 10/15
# 57/57 [==============================] - 1927s 34s/step - loss: 0.6259 - accuracy: 0.8117 - val_loss: 1.3149 - val_accuracy: 0.5542
# Epoch 11/15
# 57/57 [==============================] - 1460s 25s/step - loss: 0.4881 - accuracy: 0.8659 - val_loss: 1.3067 - val_accuracy: 0.5863
# Epoch 12/15
# 57/57 [==============================] - 1588s 28s/step - loss: 0.3567 - accuracy: 0.9186 - val_loss: 1.2586 - val_accuracy: 0.5946
# Epoch 13/15
# 57/57 [==============================] - 1875s 33s/step - loss: 0.3824 - accuracy: 0.8983 - val_loss: 1.2939 - val_accuracy: 0.5935
# Epoch 14/15
# 57/57 [==============================] - 2341s 41s/step - loss: 0.2881 - accuracy: 0.9346 - val_loss: 1.3970 - val_accuracy: 0.5623
# Epoch 15/15
# 57/57 [==============================] - 1521s 26s/step - loss: 0.1925 - accuracy: 0.9709 - val_loss: 1.3945 - val_accuracy: 0.5726

# %%
AlexNet.save_weights('alexnet2.h5')
